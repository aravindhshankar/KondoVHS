# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
eps = 1e-6
x = np.logspace(0,3,1000) + eps
x0 = 1e-1
y = -1e-6 * np.log(np.abs(x-x0))
y -= y[-1]
#plt.plot(x,y,'p')

sel = slice(-200,-100)
y[sel_slice]

plt.loglog(x[sel],y[sel], 'p')
forfit = slice(-200,-170)
m,c = np.polyfit(np.log(x[forfit]),np.log(y[forfit]),1)
fity = m*x[sel] + c
ax = plt.gca()
ax.loglog(x[sel], np.exp(c)*(x[sel]**m), '--')
ax.set_title(' m = ' + f'{m:.2f}')
# Out:
# Text(0.5, 1.0, ' m = -0.79')

# %%
x = 0
visits = np.array([x+15, x+17, x-15, x-17, x+6, x-6, x+10,x-10])
trarray = visits//64
trarray = np.array(trarray, dtype = 'bool')
trarray = ~trarray
visits = visits[trarray]
visits, trarray
# Out:
# (array([15, 17,  6, 10]),
#  array([ True,  True, False, False,  True, False,  True, False]))

# %%
# Out:
# 1
